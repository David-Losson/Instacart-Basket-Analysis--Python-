# %% [markdown]
# # 01. Importing Libraries

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
#importing products data from the project folder
df_prods = pd.read_csv (r'C:\Users\dmlos\Instacart Basket Analysis\02 Data\Original Data\products.csv', index_col = False)

# %%
#importing orders data from the project folder
df_ords = pd.read_csv (r'C:\Users\dmlos\Instacart Basket Analysis\02 Data\Original Data\orders.csv', index_col = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20256\4058442127.py in <module>
#       1 #importing orders data from the project folder
# ----> 2 df_ords = pd.read_csv (r'C:\Users\dmlos\Instacart Basket Analysis\02 Data\Original Data\orders.csv', index_col = False)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## A.) Data Consistency Checks- Products Data

# %%
#investigating our data set
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.710542e+06  1.715486e+01
# std    9.875817e+05  9.875817e+05  9.875817e+05  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  8.552715e+05  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.710542e+06  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  2.565812e+06  2.300000e+01
# max    3.421082e+06  3.421083e+06  3.421083e+06  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
#Testing a Data Check on A Mixed Data Column

# %%
# Create a dataframe

df_test = pd.DataFrame()

# %%
# Create a mixed type column

df_test ['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Check for mixed types

for col in df_test.columns.tolist():
    weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_test[weird]) > 0:
        print(col)
# Out:
# mix

# %%
# Fixing mixed type columns

df_test['mix'] = df_test['mix'].astype('str')

# %%
# Finding missing values

df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
#Cleaned Producsts Data Frame without Duplicates
df_prods_clean_no_dups
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
path = (r'C:\Users\dmlos\Instacart Basket Analysis')

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path,'02 Data', 'Prepared Data', 'products_checked.csv'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20256\1553374615.py in <module>
# ----> 1 df_prods_clean_no_dups.to_csv(os.path.join(path,'02 Data', 'Prepared Data', 'products_checked.csv'))
#
# NameError: name 'df_prods_clean_no_dups' is not defined

# %% [markdown]
# ## B.) Data Consistency Checks- Orders Data

# %%
# investigating our dataset

df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.710542e+06  1.715486e+01
# std    9.875817e+05  9.875817e+05  9.875817e+05  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  8.552715e+05  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.710542e+06  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  2.565812e+06  2.300000e+01
# max    3.421082e+06  3.421083e+06  3.421083e+06  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# ##### Question 2.) A preliminary run through of the numbers actually reveals a pretty logically-consistent set of data- the counts for each column are all the consistent, a good sign. The minimum, maximum, and quartile values make sense for the fields to which they apply (i..e orders_day_of_the_week, Order_hour_of_day, and days_since_prior_order.)

# %%
# Check for mixed types

for col in df_ords.columns.tolist():
    weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_ords[weird]) > 0:
        print(col)

# %%
# Check for missing values

df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# ##### Question 5.) There are 206,209 missing values for days_since_prior_order. I believe this result comes from the fact that there are quite a few entries for same-day orders (i.e. 0 days since prior order). Because those orders were made the same day, they were left blank in the "days since prior order" field.

# %% [markdown]
# ##### Question 6.) For the blank values, I would impute a value of '0'.

# %%
#Impute values of '0' for missing or blank values in the 'days_since_prior_order' column.

df_ords['days_since_prior_order'].fillna (0, inplace = True)

# %%
#Look at df_ords with imputed values.

df_ords
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329  2539329    prior             1
# 1                 1   2398795  2398795    prior             2
# 2                 2    473747   473747    prior             3
# 3                 3   2254736  2254736    prior             4
# 4                 4    431534   431534    prior             5
# ...             ...       ...      ...      ...           ...
# 3421078     3421078   2266710  2266710    prior            10
# 3421079     3421079   1854736  1854736    prior            11
# 3421080     3421080    626363   626363    prior            12
# 3421081     3421081   2977660  2977660    prior            13
# 3421082     3421082    272231   272231    train            14
#
#          orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                         2                  8                     0.0
# 1                         3                  7                    15.0
# ...

# %% [markdown]
# ##### Question 7.)  In the ".duplicated()" function below, no duplicate rows were found.

# %%
#Looking for duplicate rows in the df_ords dataset.

df_dups = df_ords[df_ords.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %% [markdown]
# ##### Question 8.) Truthfully, I didn't find any "full duplicate" values, so, there was no action needed to address duplicates.

# %%
path = (r'C:\Users\dmlos\Instacart Basket Analysis')

# %%
df_ords.to_csv(os.path.join(path,'02 Data', 'Prepared Data', 'orders_checked.csv'))

# %%
df_prods.to_csv(os.path.join(path,'02 Data', 'Prepared Data', 'products_checked(3).csv'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20256\297333623.py in <module>
# ----> 1 df_prods.to_csv(os.path.join(path,'02 Data', 'Prepared Data', 'products_checked(3).csv'))
#
# NameError: name 'df_prods' is not defined
